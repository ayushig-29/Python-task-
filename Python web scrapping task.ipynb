# %% [markdown]
# # Automation Script for the given website

# %%
import requests
from bs4 import BeautifulSoup
import json
from prettytable import PrettyTable

# %%
baseurl = " https://www.midsouthshooterssupply.com/dept/reloading/primers?currentpage=1"

# %%
product_details=[]
product_title =[]
product_price=[]
product_manufct=[]
product_stock=[]

# %%
for page_no in range(1, 3):
    r = requests.get('https://www.midsouthshooterssupply.com/dept/reloading/primers?currentpage={x}')
    soup = BeautifulSoup(r.text, 'html.parser')
    prod = soup.find_all(id="Div1",class_="product")

    for pr in prod:
        product_title.append(pr.find('a',class_="catalog-item-name").get_text())
        product_price.append(pr.find('span',class_="price").get_text())
        product_manufct.append(pr.find('a',class_="catalog-item-brand").get_text())
        product_stock.append(("true","false")[pr.find('span',class_="out-of-stock").get_text()=="Out of Stock"])
        per_details = {"title":None,"price":None,"maftr":None,"In-stock":None}
        per_details["title"] = pr.find('a',class_="catalog-item-name").get_text()
        per_details["price"] = pr.find('span',class_="price").get_text()
        per_details["maftr"] = pr.find('a',class_="catalog-item-brand").get_text()
        per_details["In-stock"]=("true","false")[pr.find('span',class_="out-of-stock").get_text()=="Out of Stock"]
        product_details.append(per_details)

# %%
print(product_details)
# Out:
# [{'title': 'Winchester USA Ready Match Large Pistol Primers 1000 Count', 'price': '$48.43', 'maftr': 'Winchester', 'In-stock': 'false'}, {'title': 'Winchester USA Ready Match Large Rifle Primers 1000 Count', 'price': '$38.99', 'maftr': 'Winchester', 'In-stock': 'false'}, {'title': 'Winchester USA Ready Match Small Pistol Primers 1000 Count', 'price': '$38.99', 'maftr': 'Winchester', 'In-stock': 'false'}, {'title': 'Winchester USA Ready Match Small Rifle Primers 1000 Count', 'price': '$38.99', 'maftr': 'Winchester', 'In-stock': 'false'}, {'title': 'Winchester Small Pistol Primers 1000 Count', 'price': '$41.33', 'maftr': 'Winchester', 'In-stock': 'false'}, {'title': 'Winchester Large Pistol Primers 1000 Count', 'price': '$41.33', 'maftr': 'Winchester', 'In-stock': 'false'}, {'title': 'Winchester Small Rifle Primers 1000 Count', 'price': '$41.33', 'maftr': 'Winchester', 'In-stock': 'false'}, {'title': 'Winchester Large Rifle Primers 1000 Count', 'price': '$41.33', 'maftr': 'Winchester', 'In-stock': 'false'}, {'title': '#200 Large Rifle Primer (1000 Count)', 'price': '$40.75', 'maftr': 'CCI ', 'In-stock': 'false'}, {'title': 'Winchester Small Pistol Magnum Primers 1000 Count', 'price': '$41.33', 'maftr': 'Winchester', 'In-stock': 'false'}, {'title': 'Winchester Magnum Large Rifle Primers 1000 Count', 'price': '$45.53', 'maftr': 'Winchester', 'In-stock': 'false'}, {'title': '#450 Magnum Small Rifle Primer (1000 Count)', 'price': '$44.95', 'maftr': 'CCI ', 'In-stock': 'false'}, {'title': '#250 Magnum Large Rifle Primer (1000 Count)', 'price': '$44.95', 'maftr': 'CCI ', 'In-stock': 'false'}, {'title': '#550 Magnum Small Pistol Primer (1000 Count)', 'price': '$40.75', 'maftr': 'CCI ', 'In-stock': 'false'}, {'title': '#350 Magnum Large Pistol Primer (1000 Count)', 'price': '$44.95', 'maftr': 'CCI ', 'In-stock': 'false'}, {'title': 'Gold Medal Large Rifle Match Primer #GM210M (1000 Count)', 'price': '$48.14', 'maftr': 'Federal ', 'In-stock': 'false'}, {'title': 'BR4 Small Rifle Bench Rest Primer (1000 Count)', 'price': '$69.16', 'maftr': 'CCI ', 'In-stock': 'false'}, {'title': '#35 50 Caliber BMG Primer (500 Count)', 'price': '$261.07', 'maftr': 'CCI ', 'In-stock': 'false'}, {'title': '1 1/2 Small Pistol Primer (1000 Count)', 'price': '$32.37', 'maftr': 'Remington', 'In-stock': 'false'}, {'title': '2 1/2 Large Pistol Primer (1000 Count)', 'price': '$32.37', 'maftr': 'Remington', 'In-stock': 'false'}, {'title': '6 1/2 Small Rifle Primer (1000 Count)', 'price': '$32.37', 'maftr': 'Remington', 'In-stock': 'false'}, {'title': '9 1/2 Large Rifle Primer (1000 Count)', 'price': '$32.37', 'maftr': 'Remington', 'In-stock': 'false'}, {'title': '9 1/2 Magnum Large Rifle Primer (1000 Count)', 'price': '$34.97', 'maftr': 'Remington', 'In-stock': 'false'}, {'title': '5 1/2 Small Mag Pistol Primer (1000 Count)', 'price': '$32.37', 'maftr': 'Remington', 'In-stock': 'false'}, {'title': '7 1/2 Bench Rest Small Rifle Primer (1000 Count)', 'price': '$32.37', 'maftr': 'Remington', 'In-stock': 'false'}, {'title': '209 Premier STS Shotshell Primer (1000 Count)', 'price': '$49.79', 'maftr': 'Remington', 'In-stock': 'false'}, {'title': 'Winchester Shot Shell Primers 1000 Count', 'price': '$32.99', 'maftr': 'Winchester', 'In-stock': 'false'}, {'title': 'Federal Small Pistol Primer #100 (1000 Count)', 'price': '$41.91', 'maftr': 'Federal ', 'In-stock': 'false'}, {'title': 'Large Pistol Primer #150 (1000 Count)', 'price': '$41.91', 'maftr': 'Federal ', 'In-stock': 'false'}, {'title': 'Magnum Large Pistol Primer #155 (1000 Count)', 'price': '$46.26', 'maftr': 'Federal ', 'In-stock': 'false'}, {'title': 'Winchester USA Ready Match Large Pistol Primers 1000 Count', 'price': '$48.43', 'maftr': 'Winchester', 'In-stock': 'false'}, {'title': 'Winchester USA Ready Match Large Rifle Primers 1000 Count', 'price': '$38.99', 'maftr': 'Winchester', 'In-stock': 'false'}, {'title': 'Winchester USA Ready Match Small Pistol Primers 1000 Count', 'price': '$38.99', 'maftr': 'Winches ...

# %% [markdown]
# **JSON FORMAT**

# %%
for prd in product_details:
    json_obj=json.dumps(prd,indent=4)
    print(json_obj)
# Out:
# {
#     "title": "Winchester USA Ready Match Large Pistol Primers 1000 Count",
#     "price": "$48.43",
#     "maftr": "Winchester",
#     "In-stock": "false"
# }
# {
#     "title": "Winchester USA Ready Match Large Rifle Primers 1000 Count",
#     "price": "$38.99",
#     "maftr": "Winchester",
#     "In-stock": "false"
# }
# {
#     "title": "Winchester USA Ready Match Small Pistol Primers 1000 Count",
#     "price": "$38.99",
#     "maftr": "Winchester",
#     "In-stock": "false"
# }
# {
#     "title": "Winchester USA Ready Match Small Rifle Primers 1000 Count",
#     "price": "$38.99",
#     "maftr": "Winchester",
#     "In-stock": "false"
# }
# {
#     "title": "Winchester Small Pistol Primers 1000 Count",
#     "price": "$41.33",
#     "maftr": "Winchester",
#     "In-stock": "false"
# }
# {
#     "title": "Winchester Large Pistol Primers 1000 Count",
#     "price": "$41.33",
#     "maftr": "Winchester",
#     "In-stock": "false"
# }
# {
#     "title": "Winchester Small Rifle Primers 1000 Count",
#     "price": "$41.33",
#     "maftr": "Winchester",
#     "In-stock": "false"
# }
# {
#     "title": "Winchester Large Rifle Primers 1000 Count",
#     "price": "$41.33",
#     "maftr": "Winchester",
#     "In-stock": "false"
# }
# {
#     "title": "#200 Large Rifle Primer (1000 Count)",
#     "price": "$40.75",
#     "maftr": "CCI ",
#     "In-stock": "false"
# }
# {
#     "title": "Winchester Small Pistol Magnum Primers 1000 Count",
#     "price": "$41.33",
#     "maftr": "Winchester",
#     "In-stock": "false"
# }
# {
#     "title": "Winchester Magnum Large Rifle Primers 1000 Count",
#     "price": "$45.53",
#     "maftr": "Winchester",
#     "In-stock": "false"
# }
# {
#     "title": "#450 Magnum Small Rifle Primer (1000 Count)",
#     "price": "$44.95",
#     "maftr": "CCI ",
#     "In-stock": "false"
# }
# {
#     "title": "#250 Magnum Large Rifle Primer (1000 Count)",
#     "price": "$44.95",
#     "maftr": "CCI ",
#     "In-stock": "false"
# }
# {
#     "title": "#550 Magnum Small Pistol Primer (1000 Count)",
#     "price": "$40.75",
#     "maftr": "CCI ",
#     "In-stock": "false"
# }
# {
#     "title": "#350 Magnum Large Pistol Primer (1000 Count)",
#     "price": "$44.95",
#     "maftr": "CCI ",
#     "In-stock": "false"
# }
# {
#     "title": "Gold Medal Large Rifle Match Primer #GM210M (1000 Count)",
#     "price": "$48.14",
#     "maftr": "Federal ",
#     "In-stock": "false"
# }
# {
#     "title": "BR4 Small Rifle Bench Rest Primer (1000 Count)",
#     "price": "$69.16",
#     "maftr": "CCI ",
#     "In-stock": "false"
# }
# {
#     "title": "#35 50 Caliber BMG Primer (500 Count)",
#     "price": "$261.07",
#     "maftr": "CCI ",
#     "In-stock": "false"
# }
# {
#     "title": "1 1/2 Small Pistol Primer (1000 Count)",
#     "price": "$32.37",
#     "maftr": "Remington",
#     "In-stock": "false"
# }
# {
#     "title": "2 1/2 Large Pistol Primer (1000 Count)",
#     "price": "$32.37",
#     "maftr": "Remington",
#     "In-stock": "false"
# }
# {
#     "title": "6 1/2 Small Rifle Primer (1000 Count)",
#     "price": "$32.37",
#     "maftr": "Remington",
#     "In-stock": "false"
# }
# {
#     "title": "9 1/2 Large Rifle Primer (1000 Count)",
#     "price": "$32.37",
#     "maftr": "Remington",
#     "In-stock": "false"
# }
# {
#     "title": "9 1/2 Magnum Large Rifle Primer (1000 Count)",
#     "price": "$34.97",
#     "maftr": "Remington",
#     "In-stock": "false"
# }
# {
#     "title": "5 1/2 Small Mag Pistol Primer (1000 Count)",
#     "price": "$32.37",
#     "maftr": "Remington",
#     "In-stock": "false"
# }
# {
#     "title": "7 1/2 Bench Rest Small Rifle Primer (1000 Count)",
#     "price": "$32.37",
#     "maftr": "Remington",
#     "In-stock": "false"
# }
# {
#     "title": "209 Premier STS Shotshell Primer (1000 Count)",
#     "price": "$49.79",
#     "maftr": "Remington",
#     "In-stock": "false"
# }
# {
#     "title": "Winchester Shot Shell Primers 1000 Count",
#     "price": "$32.99",
#     "maftr": "Winchester",
#     "In-stock": "false"
# }
# {
#     "title": "Federal Small Pistol Primer #100 (1000 Count)",
#     "price": "$41.91",
#     "maftr": "Federal ",
#     "In-stock": "false"
# }
# {
#     "title": "Large Pistol Primer #150 (1000 Count)",
#     "price": "$41.91",
#     "maftr": "Federal ",
#     "In-stock": "false"
# }
# {
#     "title": "Magnum Large Pistol Primer #155 (1000 Count)",
#     "price": "$46.26",
#     "maftr": "Federal ",
#     "In-stock": "false"
# }
# {
#     "title": "Winchester USA Ready Match Large Pistol Primers 1000 Count",
#     "price": "$48.43",
#     "maftr": "Winchester",
#     "In-stock": "false"
# }
# {
#     "title": "Winchester USA Ready Match Large Rifle Primers 1000 Count",
#     "price": "$38.99",
#     "maftr": "Winchester",
#     "In-stock": "false"
# }
# {
#     "title": "Winchester USA Ready Match Small Pistol Primers 1000 Count",
#     "price": "$38.99",
#     "maftr": "Winchester",
#     "In-stock": "false"
# }
# {
#     "title": "Winchester USA Ready Match Small Rifle Primers 1000 Count",
#     "price": "$38.99",
#     "maftr": "Winchester",
#     "In-stock": "false"
# }
# {
#     "title": "Winchester Small Pistol Primers 1000 Count",
#     "price": "$41.33",
#     "maftr": "Winchester",
#     "In-stock": "false"
# }
# {
#     "title": "Winchester Large Pistol Primers 1000 Count",
#     "price": "$41.33",
#     "maftr": "Winchester",
#     "In-stock": "false"
# }
# {
#     "title": "Winchester Small Rifle Primers 1000 Count",
#     "price": "$41.33",
#     "maftr": "Winchester",
#     "In-stock": "false"
# }
# {
#     "title": "Winchester Large Rifle Primers 1000 Count",
#     "price": "$41.33",
#     "maftr": "Winchester",
#     "In-stock": "false"
# }
# {
#     "title": "#200 Large Rifle Primer (1000 Count)",
#     "price": "$40.75",
#     "maftr": "CCI ",
#     "In-stock": "false"
# }
# {
#     "title": "Winchester Small Pistol Magnum Primers 1000 Count",
#     "price": "$41.33",
#     "maftr": "Winchester",
#     "In-stock": "false"
# }
# {
#     "title": "Winchester Magnum Large Rifle Primers 1000 Count",
#     "price": "$45.53",
#     "maftr": "Winchester",
#     "In-stock": "false"
# }
# {
#     "title": "#450 Magnum Small Rifle Primer (1000 Count)",
#     "price": "$44.95",
#     "maftr": "CCI ",
#     "In-stock": "false"
# }
# {
#     "title": "#250 Magnum Large Rifle Primer (1000 Count)",
#     "price": "$44.95",
#     "maftr": "CCI ",
#     "In-stock": "false"
# }
# {
#     "title": "#550 Magnum Small Pistol Primer (1000 Count)",
#     "price": "$40.75",
#     "maftr": "CCI ",
#     "In-stock": "false"
# }
# {
#     "title": "#350 Magnum Large Pistol Primer (1000 Count)",
#     "price": "$44.95",
#     "maftr": "CCI ",
#     "In-stock": "false"
# }
# {
#     "title": "Gold Medal Large Rifle Match Primer #GM210M (1000 Count)",
#     "price": "$48.14",
#     "maftr": "Federal ",
#     "In-stock": "false"
# }
# {
#     "title": "BR4 Small Rifle Bench Rest Primer (1000 Count)",
#     "price": "$69.16",
#     "maftr": "CCI ",
#     "In-stock": "false"
# }
# {
#     "title": "#35 50 Caliber BMG Primer (500 Count)",
#     "price": "$261.07",
#     "maftr": "CCI ",
#     "In-stock": "false"
# }
# {
#     "title": "1 1/2 Small Pistol Primer (1000 Count)",
#     "price": "$32.37",
#     "maftr": "Remington",
#     "In-stock": "false"
# }
# {
#     "title": "2 1/2 Large Pistol Primer (1000 Count)",
#     "price": "$32.37",
#     "maftr": "Remington",
#     "In-stock": "false"
# }
# {
#     "title": "6 1/2 Small Rifle Primer (1000 Count)",
#     "price": "$32.37",
#     "maftr": "Remington",
#     "In-stock": "false"
# }
# {
#     "title": "9 1/2 Large Rifle Primer (1000 Count)",
#     "price": "$32.37",
#     "maftr": "Remington",
#     "In-stock": "false"
# }
# {
#     "title": "9 1/2 Magnum Large Rifle Primer (1000 Count)",
#     "price": "$34.97",
#     "maftr": "Remington",
#     "In-stock": "false"
# }
# {
#     "title": "5 1/2 Small Mag Pistol Primer (1000 Count)",
#     "price": "$32.37",
#     "maftr": "Remington",
#     "In-stock": "false"
# }
# {
#     "title": "7 1/2 Bench Rest Small Rifle Primer (1000 Count)",
#     "price": "$32.37",
#     "maftr": "Remington",
#     "In-stock": "false"
# }
# {
#     "title": "209 Premier STS Shotshell Primer (1000 Count)",
#     "price": "$49.79",
#     "maftr": "Remington",
#     "In-stock": "false"
# }
# {
#     "title": "Winchester Shot Shell Primers 1000 Count",
#     "price": "$32.99",
#     "maftr": "Winchester",
#     "In-stock": "false"
# }
# {
#     "title": "Federal Small Pistol Primer #100 (1000 Count)",
#     "price": "$41.91",
#     "maftr": "Federal ",
#     "In-stock": "false"
# }
# {
#     "title": "Large Pistol Primer #150 (1000 Count)",
#     "price": "$41.91",
#     "maftr": "Federal ",
#     "In-stock": "false"
# }
# {
#     "title": "Magnum Large Pistol Primer #155 (1000 Count)",
#     "price": "$46.26",
#     "maftr": "Federal ",
#     "In-stock": "false"
# }

# %% [markdown]
# **Table Format**

# %%
myTable = PrettyTable(["Title", "Price", "Maftr", "In-Stock"]) 
for item in product_details:
    myTable.add_row([item["title"], item["price"], item["maftr"], item["In-stock"]])
print(myTable)
# Out:
# +------------------------------------------------------------+---------+------------+----------+
# |                           Title                            |  Price  |   Maftr    | In-Stock |
# +------------------------------------------------------------+---------+------------+----------+
# | Winchester USA Ready Match Large Pistol Primers 1000 Count |  $48.43 | Winchester |  false   |
# | Winchester USA Ready Match Large Rifle Primers 1000 Count  |  $38.99 | Winchester |  false   |
# | Winchester USA Ready Match Small Pistol Primers 1000 Count |  $38.99 | Winchester |  false   |
# | Winchester USA Ready Match Small Rifle Primers 1000 Count  |  $38.99 | Winchester |  false   |
# |         Winchester Small Pistol Primers 1000 Count         |  $41.33 | Winchester |  false   |
# |         Winchester Large Pistol Primers 1000 Count         |  $41.33 | Winchester |  false   |
# |         Winchester Small Rifle Primers 1000 Count          |  $41.33 | Winchester |  false   |
# |         Winchester Large Rifle Primers 1000 Count          |  $41.33 | Winchester |  false   |
# |            #200 Large Rifle Primer (1000 Count)            |  $40.75 |    CCI     |  false   |
# |     Winchester Small Pistol Magnum Primers 1000 Count      |  $41.33 | Winchester |  false   |
# |      Winchester Magnum Large Rifle Primers 1000 Count      |  $45.53 | Winchester |  false   |
# |        #450 Magnum Small Rifle Primer (1000 Count)         |  $44.95 |    CCI     |  false   |
# |        #250 Magnum Large Rifle Primer (1000 Count)         |  $44.95 |    CCI     |  false   |
# |        #550 Magnum Small Pistol Primer (1000 Count)        |  $40.75 |    CCI     |  false   |
# |        #350 Magnum Large Pistol Primer (1000 Count)        |  $44.95 |    CCI     |  false   |
# |  Gold Medal Large Rifle Match Primer #GM210M (1000 Count)  |  $48.14 |  Federal   |  false   |
# |       BR4 Small Rifle Bench Rest Primer (1000 Count)       |  $69.16 |    CCI     |  false   |
# |           #35 50 Caliber BMG Primer (500 Count)            | $261.07 |    CCI     |  false   |
# |           1 1/2 Small Pistol Primer (1000 Count)           |  $32.37 | Remington  |  false   |
# |           2 1/2 Large Pistol Primer (1000 Count)           |  $32.37 | Remington  |  false   |
# |           6 1/2 Small Rifle Primer (1000 Count)            |  $32.37 | Remington  |  false   |
# |           9 1/2 Large Rifle Primer (1000 Count)            |  $32.37 | Remington  |  false   |
# |        9 1/2 Magnum Large Rifle Primer (1000 Count)        |  $34.97 | Remington  |  false   |
# |         5 1/2 Small Mag Pistol Primer (1000 Count)         |  $32.37 | Remington  |  false   |
# |      7 1/2 Bench Rest Small Rifle Primer (1000 Count)      |  $32.37 | Remington  |  false   |
# |       209 Premier STS Shotshell Primer (1000 Count)        |  $49.79 | Remington  |  false   |
# |          Winchester Shot Shell Primers 1000 Count          |  $32.99 | Winchester |  false   |
# |       Federal Small Pistol Primer #100 (1000 Count)        |  $41.91 |  Federal   |  false   |
# |           Large Pistol Primer #150 (1000 Count)            |  $41.91 |  Federal   |  false   |
# |        Magnum Large Pistol Primer #155 (1000 Count)        |  $46.26 |  Federal   |  false   |
# | Winchester USA Ready Match Large Pistol Primers 1000 Count |  $48.43 | Winchester |  false   |
# | Winchester USA Ready Match Large Rifle Primers 1000 Count  |  $38.99 | Winchester |  false   |
# | Winchester USA Ready Match Small Pistol Primers 1000 Count |  $38.99 | Winchester |  false   |
# | Winchester USA Ready Match Small Rifle Primers 1000 Count  |  $38.99 | Winchester |  false   |
# |         Winchester Small Pistol Primers 1000 Count         |  $41.33 | Winchester |  false   |
# |         Winchester Large Pistol Primers 1000 Count         |  $41.33 | Winchester |  false   |
# |         Winchester Small Rifle Primers 1000 Count          |  $41.33 | Winchester |  false   |
# |         Winchester Large Rifle Primers 1000 Count          |  $41.33 | Winchester |  false   |
# |            #200 Large Rifle Primer (1000 Count)            |  $40.75 |    CCI     |  false   |
# |     Winchester Small Pistol Magnum Primers 1000 Count      |  $41.33 | Winchester |  false   |
# |      Winchester Magnum Large Rifle Primers 1000 Count      |  $45.53 | Winchester |  false   |
# |        #450 Magnum Small Rifle Primer (1000 Count)         |  $44.95 |    CCI     |  false   |
# |        #250 Magnum Large Rifle Primer (1000 Count)         |  $44.95 |    CCI     |  false   |
# |        #550 Magnum Small Pistol Primer (1000 Count)        |  $40.75 |    CCI     |  false   |
# |        #350 Magnum Large Pistol Primer (1000 Count)        |  $44.95 |    CCI     |  false   |
# |  Gold Medal Large Rifle Match Primer #GM210M (1000 Count)  |  $48.14 |  Federal   |  false   |
# |       BR4 Small Rifle Bench Rest Primer (1000 Count)       |  $69.16 |    CCI     |  false   |
# |           #35 50 Caliber BMG Primer (500 Count)            | $261.07 |    CCI     |  false   |
# |           1 1/2 Small Pistol Primer (1000 Count)           |  $32.37 | Remington  |  false   |
# |           2 1/2 Large Pistol Primer (1000 Count)           |  $32.37 | Remington  |  false   |
# |           6 1/2 Small Rifle Primer (1000 Count)            |  $32.37 | Remington  |  false   |
# |           9 1/2 Large Rifle Primer (1000 Count)            |  $32.37 | Remington  |  false   |
# |        9 1/2 Magnum Large Rifle Primer (1000 Count)        |  $34.97 | Remington  |  false   |
# |         5 1/2 Small Mag Pistol Primer (1000 Count)         |  $32.37 | Remington  |  false   |
# |      7 1/2 Bench Rest Small Rifle Primer (1000 Count)      |  $32.37 | Remington  |  false   |
# |       209 Premier STS Shotshell Primer (1000 Count)        |  $49.79 | Remington  |  false   |
# |          Winchester Shot Shell Primers 1000 Count          |  $32.99 | Winchester |  false   |
# |       Federal Small Pistol Primer #100 (1000 Count)        |  $41.91 |  Federal   |  false   |
# |           Large Pistol Primer #150 (1000 Count)            |  $41.91 |  Federal   |  false   |
# |        Magnum Large Pistol Primer #155 (1000 Count)        |  $46.26 |  Federal   |  false   |
# +------------------------------------------------------------+---------+------------+----------+
